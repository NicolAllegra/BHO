# %%
import sarfa_saliency


dict_q_vals_before_perturbation, original_action = RL_agent.q_values(state) # this is a dictionary, where the key is an action, and the value is the q-value of that action for this state 

# now perturb the state, this step depends on your domain 
# if you are using images or chess boards, you can use the perturbtations provided in our examples 
perturbed_state = perturb(state)

dict_q_vals_after_perturbation = RL_agent.q_values(perturbed_state)

saliency = sarfa_saliency.computeSaliencyUsingSarfa(original_action, dict_q_vals_before_perturbation, dict_q_vals_after_perturbation)

# that's all folks

# %%
import json 
import pandas as pd 
from pandas.io.json import json_normalize #package for flattening json in pandas df

#load json object
with open('chess_saliency_databases\\chess-saliency-dataset-v1.json') as f:
    d = json.load(f)


nycphil = json_normalize(d['puzzles'])
# Out:
# C:\Users\Nicol\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if sys.path[0] == '':

# %%
nycphil
# Out:
#                                                    fen  \
# 0    2r2rk1/pp1bqpp1/2nppn1p/2p3N1/1bP5/1PN3P1/PBQP...
# 1    r2qrbk1/1bp2ppp/p2p1n2/2p2NB1/4P3/2N2Q2/PPP2PP...
# 2    2r4k/3r1p1p/1p2pP2/p2pPp1P/P2P1Q2/6R1/4B1PK/2q...
# 3    R4rk1/5bb1/1N1Qpq1p/3pn1p1/3N4/2P2P1P/P5P1/5B1...
# 4    5r1k/bp4pp/1n6/5qN1/1PR5/P2Q3P/5PP1/6K1 w - - 0 1
# ..                                                 ...
# 97   8/1p3pkp/2rQ1p2/3b1q2/5B2/P6P/1P2R1PK/8 w - - 0 1
# 98   3r2b1/p1Q3R1/6pk/2p4p/4Np1q/1PPB1P2/3K4/8 w - ...
# 99               3n4/8/pppN4/k7/2P5/1K6/P7/8 w - - 0 1
# 100           6k1/8/2R4p/8/5qp1/P7/6P1/1R4K1 w - - 0 2
# 101  3r1q1k/pQ3B1p/8/3R2p1/6b1/6P1/PP2r2P/5RK1 w - ...
#
#                   responseMoves           saliencyGroundTruth  \
# 0                  [exd5, hxg5]  [c3, c2, f8, b2, f7, e7, g5]
# 1                   [gxh6, Bg7]  [f5, f7, g5, f3, g7, d8, f6]
# 2                            []          [g3, f7, f6, f4, c1]
# 3                  [exd5, Bxf8]      [b6, a8, d6, d5, f3, e6]
# 4                            []      [c4, g2, f2, g5, g7, d3]
# ..                          ...                           ...
# 97                  [Kxf8, Kg8]          [d6, h7, f7, e2, f4]
# 98                  [Kxg6, Kf6]          [d3, g7, h5, c7, h4]
# 99                         [b5]              [c4, a2, a6, d6]
# 100  [Kg7, Kg6, Kh5, Kh4, Kxg4]              [c6, f4, b1, a3]
# 101            [Qxb4, Kg7, Kh6]          [b7, h7, f7, f1, d5]
#
#                                  solution
# 0                       [Nd5, Bxf6, Bxe7]
# 1                      [Nh6+, Bxf6, Bxd8]
# 2                                  [Rg8+]
# 3                     [Nxd5, Rxf8+, Qxf6]
# 4                                   [Rf4]
# ..                                    ...
# 97                     [Qf8+, Bh6+, Re8#]
# 98                   [Rxg6+, Nd6+, Qxd8+]
# 99                               [c5, a3]
# 100  [Rc8+, Rb7+, Rg8+, Rb5+, Rxg4+, Rb4]
# 101              [Qb4, Rxd8+, Rg8+, Rf6#]
#
# [102 rows x 4 columns]
